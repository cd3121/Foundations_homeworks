# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors')
doc = BeautifulSoup(response.text)

# %%
books = doc.find_all('tr', itemtype="http://schema.org/Book")
rows = []
for book in books:
    row ={}
    row['rank'] = book.find(class_="number").text.strip()
    row['title'] = book.find(class_="bookTitle").text.strip()
    row['author'] = book.find(class_="authorName").text.strip()
    row['score'] = book.find(onclick="Lightbox.showBoxByID('score_explanation', 300); return false;").text.strip()
    row['votes'] = book.find('a', href="#").find_next_sibling('a').text.strip()
    row['rating'] = book.find(class_="minirating").text.strip()
    rows.append(row)
#    print(rank, title, author, score, votes, rating)
df = pd.DataFrame(rows)
df.head()
# Out:
#                         author rank                               rating  \
# 0              Margaret Atwood    1  4.09 avg rating — 1,101,568 ratings
# 1              Suzanne Collins    2  4.33 avg rating — 5,741,857 ratings
# 2  Mary Wollstonecraft Shelley    3  3.78 avg rating — 1,023,245 ratings
# 3            Madeleine L'Engle    4    4.01 avg rating — 902,852 ratings
# 4            Ursula K. Le Guin    5     4.06 avg rating — 98,748 ratings
#
#            score                                         title  \
# 0  score: 30,733                           The Handmaid's Tale
# 1  score: 28,553       The Hunger Games (The Hunger Games, #1)
# 2  score: 21,909                                  Frankenstein
# 3  score: 18,720          A Wrinkle in Time (Time Quintet, #1)
# 4  score: 17,920  The Left Hand of Darkness (Hainish Cycle #4)
#
#               votes
# 0  314 people voted
# 1  292 people voted
# 2  224 people voted
# 3  196 people voted
# 4  184 people voted

# %%
df.to_csv("books.csv", index=False)

# %%
df = pd.read_csv("books.csv")
df.head()
# Out:
#                         author  rank                               rating  \
# 0              Margaret Atwood     1  4.09 avg rating — 1,101,568 ratings
# 1              Suzanne Collins     2  4.33 avg rating — 5,741,857 ratings
# 2  Mary Wollstonecraft Shelley     3  3.78 avg rating — 1,023,245 ratings
# 3            Madeleine L'Engle     4    4.01 avg rating — 902,852 ratings
# 4            Ursula K. Le Guin     5     4.06 avg rating — 98,748 ratings
#
#            score                                         title  \
# 0  score: 30,733                           The Handmaid's Tale
# 1  score: 28,553       The Hunger Games (The Hunger Games, #1)
# 2  score: 21,909                                  Frankenstein
# 3  score: 18,720          A Wrinkle in Time (Time Quintet, #1)
# 4  score: 17,920  The Left Hand of Darkness (Hainish Cycle #4)
#
#               votes
# 0  314 people voted
# 1  292 people voted
# 2  224 people voted
# 3  196 people voted
# 4  184 people voted

# %%
import re

# %%
df.columns
# Out:
# Index(['author', 'rank', 'rating', 'score', 'title', 'votes'], dtype='object')

# %%
df['score'] = df['score'].str.extract(r"score\s(.*)")
df['Series'] = df.title.str.extract(r"[(](.*\w\D)[,?|#]")

#df['title'] = df.title.str.extract(r"[(](.*)[,|#]")
df
# Out:
#                          author  rank  \
# 0               Margaret Atwood     1
# 1               Suzanne Collins     2
# 2   Mary Wollstonecraft Shelley     3
# 3             Madeleine L'Engle     4
# 4             Ursula K. Le Guin     5
# 5                 Veronica Roth     6
# 6               Suzanne Collins     7
# 7                    Lois Lowry     8
# 8             Octavia E. Butler     9
# 9             Ursula K. Le Guin    10
# 10              Margaret Atwood    11
# 11              Suzanne Collins    12
# 12           Audrey Niffenegger    13
# 13                Connie Willis    14
# 14            Ursula K. Le Guin    15
# 15                   Ann Leckie    16
# 16         Lois McMaster Bujold    17
# 17                Connie Willis    18
# 18           Mary Doria Russell    19
# 19               Anne McCaffrey    20
# 20            Octavia E. Butler    21
# 21         Lois McMaster Bujold    22
# 22         Lois McMaster Bujold    23
# 23              Stephenie Meyer    24
# 24                Veronica Roth    25
# 25         Lois McMaster Bujold    26
# 26                   P.D. James    27
# 27                 G.S. Jennsen    28
# 28              Margaret Atwood    29
# 29               Anne McCaffrey    30
# ..                          ...   ...
# 70               Elizabeth Moon    71
# 71        Marion Zimmer Bradley    72
# 72                 Hayley Stone    73
# 73                 G.S. Jennsen    74
# 74         Lois McMaster Bujold    75
# 75            Octavia E. Butler    76
# 76            Ursula K. Le Guin    77
# 77               Elizabeth Moon    78
# 78            Ursula K. Le Guin    79
# 79                  Ann Aguirre    80
# 80              Nicola Griffith    81
# 81                   Beth Revis    82
# 82                 C.J. Cherryh    83
# 83                  Mya Robarts    84
# 84                Lauren Oliver    85
# 85            Vonda N. McIntyre    86
# 86               Pamela Sargent    87
# 87                 Martha Wells    88
# 88               Elizabeth Moon    89
# 89                 C.J. Cherryh    90
# 90                 Marge Piercy    90
# 91            Maureen F. McHugh    92
# 92                   S.L. Viehl    93
# 93              Margaret Atwood    94
# 94                   Tanya Huff    95
# 95                Connie Willis    96
# 96                C.S. Friedman    97
# 97              Catherine Asaro    98
# 98                Marissa Meyer    99
# 99                  Nancy Kress   100
#
#                                               rating score  \
# 0                4.09 avg rating — 1,101,568 ratings   NaN
# 1                4.33 avg rating — 5,741,857 ratings   NaN
# 2                3.78 avg rating — 1,023,245 ratings   NaN
# 3                  4.01 avg rating — 902,852 ratings   NaN
# 4                   4.06 avg rating — 98,748 ratings   NaN
# 5                4.21 avg rating — 2,602,296 ratings   NaN
# 6                4.29 avg rating — 2,200,427 ratings   NaN
# 7                4.12 avg rating — 1,534,799 ratings   NaN
# 8                   4.23 avg rating — 72,295 ratings   NaN
# 9                   4.21 avg rating — 71,617 ratings   NaN
# 10                 4.01 avg rating — 197,737 ratings   NaN
# 11               4.03 avg rating — 2,071,712 ratings   NaN
# 12               3.96 avg rating — 1,446,554 ratings   NaN
# 13                  4.03 avg rating — 43,246 ratings   NaN
# 14                  4.11 avg rating — 43,979 ratings   NaN
# 15                  3.98 avg rating — 66,175 ratings   NaN
# 16                  4.11 avg rating — 25,864 ratings   NaN
# 17                  4.13 avg rating — 29,639 ratings   NaN
# 18                  4.17 avg rating — 52,728 ratings   NaN
# 19                 4.10 avg rating — 116,144 ratings   NaN
# 20                  4.16 avg rating — 42,215 ratings   NaN
# 21                  4.29 avg rating — 20,950 ratings   NaN
# 22                  4.31 avg rating — 22,106 ratings   NaN
# 23                 3.84 avg rating — 828,920 ratings   NaN
# 24               4.05 avg rating — 1,045,701 ratings   NaN
# 25                  4.45 avg rating — 13,944 ratings   NaN
# 26                  3.68 avg rating — 36,097 ratings   NaN
# 27                   3.91 avg rating — 2,144 ratings   NaN
# 28                  4.06 avg rating — 92,204 ratings   NaN
# 29                  4.09 avg rating — 17,772 ratings   NaN
# ..                                               ...   ...
# 70   really liked it 4.00 avg rating — 9,436 ratings   NaN
# 71                   3.88 avg rating — 5,953 ratings   NaN
# 72                     3.79 avg rating — 248 ratings   NaN
# 73                   4.22 avg rating — 1,042 ratings   NaN
# 74                  4.06 avg rating — 11,937 ratings   NaN
# 75                   4.33 avg rating — 3,944 ratings   NaN
# 76                   4.04 avg rating — 4,041 ratings   NaN
# 77                   4.06 avg rating — 3,627 ratings   NaN
# 78                  3.95 avg rating — 12,898 ratings   NaN
# 79                  3.73 avg rating — 12,658 ratings   NaN
# 80                   3.86 avg rating — 3,713 ratings   NaN
# 81                 3.77 avg rating — 107,407 ratings   NaN
# 82                   4.19 avg rating — 3,610 ratings   NaN
# 83                   4.02 avg rating — 7,833 ratings   NaN
# 84                 3.98 avg rating — 392,234 ratings   NaN
# 85                   3.86 avg rating — 8,402 ratings   NaN
# 86     really liked it 4.00 avg rating — 272 ratings   NaN
# 87                  4.15 avg rating — 35,012 ratings   NaN
# 88                  3.98 avg rating — 11,161 ratings   NaN
# 89                   4.17 avg rating — 4,058 ratings   NaN
# 90                  3.95 avg rating — 12,597 ratings   NaN
# 91                   3.94 avg rating — 3,453 ratings   NaN
# 92                   3.80 avg rating — 3,632 ratings   NaN
# 93  really liked it 4.00 avg rating — 52,186 ratings   NaN
# 94                   3.98 avg rating — 6,895 ratings   NaN
# 95                  3.93 avg rating — 10,067 ratings   NaN
# 96                   4.04 avg rating — 3,260 ratings   NaN
# 97                   3.74 avg rating — 3,686 ratings   NaN
# 98                 4.29 avg rating — 265,215 ratings   NaN
# 99                   3.61 avg rating — 1,291 ratings   NaN
#
#                                                 title             votes  \
# 0                                 The Handmaid's Tale  314 people voted
# 1             The Hunger Games (The Hunger Games, #1)  292 people voted
# 2                                        Frankenstein  224 people voted
# 3                A Wrinkle in Time (Time Quintet, #1)  196 people voted
# 4        The Left Hand of Darkness (Hainish Cycle #4)  184 people voted
# 5                           Divergent (Divergent, #1)  138 people voted
# 6                Catching Fire (The Hunger Games, #2)  133 people voted
# 7                           The Giver (The Giver, #1)  129 people voted
# 8                                             Kindred  116 people voted
# 9                 The Dispossessed (Hainish Cycle #6)  112 people voted
# 10                     Oryx and Crake (MaddAddam, #1)  107 people voted
# 11                  Mockingjay (The Hunger Games, #3)  104 people voted
# 12                           The Time Traveler's Wife   98 people voted
# 13             Doomsday Book (Oxford Time Travel, #1)   96 people voted
# 14                                The Lathe of Heaven   84 people voted
# 15              Ancillary Justice (Imperial Radch #1)   81 people voted
# 16            Shards of Honour  (Vorkosigan Saga, #1)   75 people voted
# 17  To Say Nothing of the Dog (Oxford Time Travel,...   74 people voted
# 18                      The Sparrow (The Sparrow, #1)   72 people voted
# 19            Dragonflight (Dragonriders of Pern, #1)   74 people voted
# 20               Parable of the Sower (Earthseed, #1)   71 people voted
# 21     The Warrior's Apprentice (Vorkosigan Saga, #2)   65 people voted
# 22                     Barrayar (Vorkosigan Saga, #7)   60 people voted
# 23                            The Host (The Host, #1)   56 people voted
# 24                          Insurgent (Divergent, #2)   54 people voted
# 25                      Memory (Vorkosigan Saga, #10)   51 people voted
# 26                                The Children of Men   49 people voted
# 27  Starshine: Aurora Rising Book One (Aurora Rhap...   45 people voted
# 28             The Year of the Flood  (MaddAddam, #2)   47 people voted
# 29                Crystal Singer (Crystal Singer, #1)   47 people voted
# ..                                                ...               ...
# 70                                  The Speed of Dark   24 people voted
# 71                                  Darkover Landfall   21 people voted
# 72                    Machinations (Machinations, #1)   17 people voted
# 73                      Vertigo (Aurora Rhapsody, #2)   18 people voted
# 74                    CryoBurn (Vorkosigan Saga, #14)   24 people voted
# 75              Seed to Harvest (Patternmaster, #1-4)   20 people voted
# 76                         The Wind's Twelve Quarters   19 people voted
# 77                                 Remnant Population   20 people voted
# 78                       The Word for World is Forest   20 people voted
# 79                       Grimspace (Sirantha Jax, #1)   17 people voted
# 80                                           Ammonite   20 people voted
# 81      Across the Universe (Across the Universe, #1)   16 people voted
# 82                          Inheritor (Foreigner, #3)   18 people voted
# 83                                         The V Girl   15 people voted
# 84                            Delirium (Delirium, #1)   15 people voted
# 85                                         Dreamsnake   18 people voted
# 86  Women of Wonder: Science-Fiction Stories by Wo...   16 people voted
# 87        All Systems Red (The Murderbot Diaries, #1)   14 people voted
# 88                Trading in Danger (Vatta's War, #1)   16 people voted
# 89                            Invader (Foreigner, #2)   17 people voted
# 90                          Woman on the Edge of Time   15 people voted
# 91                               China Mountain Zhang   18 people voted
# 92                              Stardoc (Stardoc, #1)   16 people voted
# 93                          MaddAddam (MaddAddam, #3)   13 people voted
# 94                 Valor's Choice (Confederation, #1)   16 people voted
# 95                                         Bellwether   13 people voted
# 96                                   This Alien Shore   15 people voted
# 97  Primary Inversion (Saga of the Skolian Empire,...   15 people voted
# 98                 Scarlet (The Lunar Chronicles, #2)   12 people voted
# 99                 Probability Moon (Probability, #1)   15 people voted
#
#                         Series
# 0                          NaN
# 1             The Hunger Games
# 2                          NaN
# 3                 Time Quintet
# 4               Hainish Cycle
# 5                    Divergent
# 6             The Hunger Games
# 7                    The Giver
# 8                          NaN
# 9               Hainish Cycle
# 10                   MaddAddam
# 11            The Hunger Games
# 12                         NaN
# 13          Oxford Time Travel
# 14                         NaN
# 15             Imperial Radch
# 16             Vorkosigan Saga
# 17          Oxford Time Travel
# 18                 The Sparrow
# 19        Dragonriders of Pern
# 20                   Earthseed
# 21             Vorkosigan Saga
# 22             Vorkosigan Saga
# 23                    The Host
# 24                   Divergent
# 25             Vorkosigan Saga
# 26                         NaN
# 27             Aurora Rhapsody
# 28                   MaddAddam
# 29              Crystal Singer
# ..                         ...
# 70                         NaN
# 71                         NaN
# 72                Machinations
# 73             Aurora Rhapsody
# 74             Vorkosigan Saga
# 75               Patternmaster
# 76                         NaN
# 77                         NaN
# 78                         NaN
# 79                Sirantha Jax
# 80                         NaN
# 81         Across the Universe
# 82                   Foreigner
# 83                         NaN
# 84                    Delirium
# 85                         NaN
# 86                         NaN
# 87       The Murderbot Diaries
# 88                 Vatta's War
# 89                   Foreigner
# 90                         NaN
# 91                         NaN
# 92                     Stardoc
# 93                   MaddAddam
# 94               Confederation
# 95                         NaN
# 96                         NaN
# 97  Saga of the Skolian Empire
# 98        The Lunar Chronicles
# 99                 Probability
#
# [100 rows x 7 columns]
